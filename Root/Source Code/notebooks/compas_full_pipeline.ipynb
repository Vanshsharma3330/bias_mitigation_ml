# %%
from src.data_loader import load_compas

df = load_compas()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.data_loader import load_compas
#       3 df = load_compas()
#       4 df.head()
#
# ModuleNotFoundError: No module named 'src'
